# %% [markdown]
# ## object detection을 위한 directory template 구성
#   - 구글 드라이브 root에 clone
#   - clone 한 workspace를 코드 디렉토리로 이동

# %%
# 구글 드라이브와 연결
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# 디렉토리 만들기
import os

if not os.path.isdir('/content/drive/MyDrive/object_detection_test/'):
  # !mkdir /content/drive/MyDrive/object_detection_test/

# %%
# 현재 디렉토리 확인
# !pwd
# Out:
# /content

# %%
# cd 명령어는 jupyter notebook의 magic command (%로 시작) 을 사용
# %cd /content/drive/MyDrive/object_detection_test/
# Out:
# /content/drive/MyDrive/object_detection_test

# %%
# directory template 다운
# !git clone https://github.com/dbgmlek/object_detection_workspace.git
# Out:
# Cloning into 'object_detection_workspace'...
# remote: Enumerating objects: 58, done.
# remote: Counting objects: 100% (58/58), done.
# remote: Compressing objects: 100% (36/36), done.
# remote: Total 58 (delta 24), reused 46 (delta 15), pack-reused 0
# Unpacking objects: 100% (58/58), done.

# %%
# 현재 경로의 파일, 디렉토리 정보 확인
# %ls -al
# Out:
# total 4
# drwx------ 6 root root 4096 Sep 29 16:46 object_detection_workspace/

# %%
# 폴더명 변경
# mv는 파일이나 폴더의 위치를 변경하는 사용
# 이름을 바꾸기 위해서도 많이 사용
# !mv 원래이름 바꿀이름

# !mv object_detection_workspace/ sign_language_letter

# %%
# %ls -al
# Out:
# total 4
# drwx------ 6 root root 4096 Sep 29 16:58 sign_language_letters/

# %%
# 특정 디렉토리에 있는 정보 확인
# !ls -al sign_language_letters
# Out:
# total 35
# drwx------ 8 root root  4096 Sep 29 16:46 .git
# -rw------- 1 root root    19 Sep 29 16:46 .gitignore
# -rw------- 1 root root 18039 Sep 29 16:46 Process.ipynb
# drwx------ 2 root root  4096 Sep 29 16:46 raw_data
# -rw------- 1 root root    63 Sep 29 16:46 README.md
# drwx------ 2 root root  4096 Sep 29 16:46 scripts
# drwx------ 6 root root  4096 Sep 29 16:46 workspace

# %% [markdown]
# ## Dataset download

# %%
import gdown # python을 이용해 구글 드라이브에 있는 파일 다운받기 위해
url = 'https://drive.google.com/uc?id=1qSkS6DaoSvVtFMlmNRssBNAb5eZRAEnI'
fname = 'american_sign_language_letters.zip'

gdown.download(url, fname, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1qSkS6DaoSvVtFMlmNRssBNAb5eZRAEnI
# To: /content/drive/My Drive/object_detection_test/american_sign_language_letters.zip
# 24.3MB [00:00, 49.2MB/s]
# 'american_sign_language_letters.zip'

# %%
# 다운받은 zip 파일을 원본 데이터를 저장하기로 정한 디렉토리로 위치 이동

# !mv american_sign_language_letters.zip /content/drive/MyDrive/object_detection_test/sign_language_letters/raw_data/
